# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('flights.csv')
df
# Out:
# /var/folders/sn/55j9sg7x7fg2w9hy06rx1sh40000gn/T/ipykernel_11704/1172302083.py:5: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('flights.csv')
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# ...

# %%
df.corr()
# Out:
# /var/folders/sn/55j9sg7x7fg2w9hy06rx1sh40000gn/T/ipykernel_11704/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      YEAR     MONTH       DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# YEAR                  NaN       NaN       NaN          NaN            NaN
# MONTH                 NaN  1.000000  0.112704    -0.015343      -0.025751
# DAY                   NaN  0.112704  1.000000     0.018385      -0.001112
# DAY_OF_WEEK           NaN -0.015343  0.018385     1.000000      -0.001689
# FLIGHT_NUMBER         NaN -0.025751 -0.001112    -0.001689       1.000000
# SCHEDULED_DEPARTURE   NaN  0.014977  0.000714     0.014971      -0.046138
# DEPARTURE_TIME        NaN  0.008298 -0.002388     0.007488      -0.015449
# ...

# %%
sns.heatmap(df.corr())
# Out:
# /var/folders/sn/55j9sg7x7fg2w9hy06rx1sh40000gn/T/ipykernel_11704/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
plt.plot(df['ARRIVAL_DELAY'],df['DEPARTURE_DELAY'])
plt.show()

# %%
df.dropna(subset=['ARRIVAL_DELAY','DEPARTURE_DELAY','AIRLINE_DELAY'],inplace=True)

# %%
sns.jointplot(x='DEPARTURE_DELAY',y='ARRIVAL_DELAY',data=df)

# %% [markdown]
# # Training

# %%
x=np.array(df['DEPARTURE_DELAY']).reshape(-1,1)
y=np.array(df['ARRIVAL_DELAY']).reshape(-1,1)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train.shape
# Out:
# (744407, 1)

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
model=reg.fit(x_train,y_train)
print(model.coef_)
print(model.intercept_)
# Out:
# [[0.91623945]]
# [8.55292578]

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[92.84695515],
#        [33.29139092],
#        [40.62130652],
#        ...,
#        [27.79395422],
#        [ 6.72044688],
#        [24.12899643]])

# %%
from sklearn import metrics
mean_abs_error=metrics.mean_absolute_error(y_pred,y_test)
mean_sqr_error=metrics.mean_squared_error(y_pred,y_test)
root_mean_error=np.sqrt(metrics.mean_squared_error(y_pred,y_test))
print(mean_abs_error)
print(mean_sqr_error)
print(root_mean_error)
# Out:
# 13.437749345692602
# 338.6479317863706
# 18.402389295587966

# %%
y_mean=df['ARRIVAL_DELAY'].mean()
squared_diff=(df['ARRIVAL_DELAY']-y_mean)**0.5
SST=squared_diff.sum()
R=(1-mean_sqr_error/SST)**0.5
print(R)
# Out:
# 0.9999254552513358

# %% [markdown]
# # GRAPH

# %%
plt.scatter(x_test,y_test,c='r',label='Actual')
plt.scatter(y_pred,y_test,c='g',label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# # Multiple_Linear_Regression

# %%
x1_train=df[['DEPARTURE_DELAY','AIRLINE_DELAY']]
y1_train=df['ARRIVAL_DELAY']
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x1_train,y1_train,test_size=0.30,random_state=42)
x1_train.shape
# Out:
# (744407, 2)

# %%
from sklearn.linear_model import LinearRegression
reg1=LinearRegression()
model_1=reg1.fit(x1_train,y1_train)
print(model_1.coef_)
print(model_1.intercept_)
# Out:
# [0.90293864 0.03000758]
# 8.714904615670697

# %%
y1_pred=model_1.predict(x1_test)
y1_pred
# Out:
# array([91.78525951, 33.90445259, 41.09795413, ..., 27.67661606,
#         6.90902734, 24.09486908])

# %%
from sklearn import metrics
mean_abs_error1=metrics.mean_absolute_error(y1_pred,y1_test)
mean_sqr_error1=metrics.mean_squared_error(y1_pred,y1_test)
root_mean_error1=np.sqrt(metrics.mean_squared_error(y1_pred,y1_test))
print(mean_abs_error1)
print(mean_sqr_error1)
print(root_mean_error1)
# Out:
# 13.4106200640539
# 337.30187306160855
# 18.36577994699949

# %%
y_mean1=df['ARRIVAL_DELAY'].mean()
squared_diff1=(df['ARRIVAL_DELAY']-y_mean1)**0.5
SST1=squared_diff1.sum()
R1=(1-mean_sqr_error1/SST1)**0.5
print(R1)
# Out:
# 0.9999257515630073

# %% [markdown]
# # Polynomial_Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures()
x2=np.array(df['DEPARTURE_DELAY']).reshape(-1,1)
X=poly.fit_transform(x2)
y2=df['ARRIVAL_DELAY']

# %%
from sklearn.model_selection import train_test_split
x2_train,x2_test,y2_train,y2_test=train_test_split(X,y2,test_size=0.30,random_state=42)
x2_train
# Out:
# array([[1.0000e+00, 1.8500e+02, 3.4225e+04],
#        [1.0000e+00, 3.3000e+01, 1.0890e+03],
#        [1.0000e+00, 1.2000e+01, 1.4400e+02],
#        ...,
#        [1.0000e+00, 4.1000e+01, 1.6810e+03],
#        [1.0000e+00, 5.0000e+00, 2.5000e+01],
#        [1.0000e+00, 1.3000e+01, 1.6900e+02]])

# %%
from sklearn.linear_model import LinearRegression
reg2=LinearRegression()
model2=reg2.fit(x2_train,y2_train)
print(model2.coef_)
print(model2.intercept_)
# Out:
# [0.00000000e+00 8.40167425e-01 1.86716626e-04]
# 11.326093465637335

# %%
y2_pred=model2.predict(x2_test)
y2_pred.shape
# Out:
# (319032,)

# %%
from sklearn import metrics
mean_abs_error2=metrics.mean_absolute_error(y2_pred,y2_test)
mean_sqr_error2=metrics.mean_squared_error(y2_pred,y2_test)
root_mean_error2=np.sqrt(metrics.mean_squared_error(y2_pred,y2_test))
print(mean_abs_error2)
print(mean_sqr_error2)
print(root_mean_error2)
# Out:
# 12.906682254531123
# 320.77719049420557
# 17.910253780843128

# %%
y_mean2=df['ARRIVAL_DELAY'].mean()
squared_diff2=(df['ARRIVAL_DELAY']-y_mean2)**0.5
SST2=squared_diff1.sum()
R2=(1-mean_sqr_error2/SST2)**0.5
print(R2)
# Out:
# 0.999929389180438

# %% [markdown]
# # Graph

# %%
plt.scatter(x2_test[:,1],y2_test,c='r',label='Actual')
plt.scatter(x2_test[:,1],y2_pred,c='g',label='Predicted')
plt.legend()
plt.show()
